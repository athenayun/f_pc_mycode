# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users//Administrator//Documents//TDCS//TDCS_20171115_M01_M08//M06//20171115//00//TDCS_M06_20171115_000000.csv', encoding = 'utf-8', header = None )

# %%
df.columns = ['car_travel_id', 'car_type', 'O_datetime', 'O_gantry', 'D_datetime', 'D_gantry', 'gantry_distance', 'interchange_distance', 'travel_end(Y/N)', 'travel_route', 'ending']

# %%
df
# Out:
#                           car_travel_id  car_type                O_datetime  \
# 0      1279a08117cd0dafc1398d110678844f        31  2017-11-15 00:00:00.000
# 1      453333ad9711300d08ac9cb2440cf012        31  2017-11-15 00:00:00.000
# 2      28dde4953c513d12a14a801684060a78        31  2017-11-15 00:00:00.000
# 3      6d8ebdc84e8ed2791ecee6a643a7194e        31  2017-11-15 00:00:00.000
# 4      8a1afcc65d5b8e99224abb6fca6d6b1e        31  2017-11-15 00:00:00.000
# 5      d1fedfc0ccfc91a63f0ea8cb80ceb8a8        31  2017-11-15 00:00:00.000
# 6      e0f97b130795c3bdaedd6ac85b1d3f0e        32  2017-11-15 00:00:00.000
# 7      afd8b6409a93d550faa5df3210fb0cfb        31  2017-11-15 00:00:00.000
# 8      9fbf069827560ea9de6d2e810d07578a         5  2017-11-15 00:00:01.000
# 9      91fb5db69ed0f28fb8f16e75664eb77e        31  2017-11-15 00:00:01.000
# 10     d7a1aada415704bdfadc4868f00de51e        31  2017-11-15 00:00:01.000
# ...

# %%
print(df[9][0].encode('utf8').split(';'))
# Out:
# ['2017-11-15 00:00:00.000+01F2156S', ' 2017-11-15 00:05:10.000+01F2249S']
