# %%
def grouping_brand(df, col_index):
    car_list = []
    for row_tuple in df.iterrows():
        tmp_list = list(row_tuple[1])
        
        #detering which car brand it belongs to
        if tmp_list[col_index] == 'ALFA ROMEO' :
            CarBrand = 'ALFA ROMEO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index] == 'ALFAROMEO' :
            CarBrand = 'ALFA ROMEO'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== ' AUDI' :
            CarBrand = 'AUDI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'AUDI' :
            CarBrand = 'AUDI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-AUDI' :
            CarBrand = 'AUDI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-ＡＵＤＩ' :
            CarBrand = 'AUDI'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'BNEZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'BWNZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'Benz 朋馳' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'CERCEDES-BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'MERCEDES' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'MERCEDES BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'MERCEDES-AMGZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'MERCEDES-BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MERCEDESBENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MERCERES-BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Mercedes-BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Mercedes-Benz' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-BENZ' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-MERCEDES-B' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '賓士' :
            CarBrand = 'BENZ'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'B.M.W' :
            CarBrand = 'BMW'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'B.M.W.' :
            CarBrand = 'BMW'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'BMW' :
            CarBrand = 'BMW'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'BMW I' :
            CarBrand = 'BMW'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'BMW 寶馬' :
            CarBrand = 'BMW'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-BMW' :
            CarBrand = 'BMW'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'BUICK' :
            CarBrand = 'BUICK'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '別克' :
            CarBrand = 'BUICK'
            tmp_list.append(CarBrand)
            
        elif tmp_list[col_index]== '必翔' :
            CarBrand = 'BYD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '必翔比亞迪' :
            CarBrand = 'BYD'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'CITROEN' :
            CarBrand = 'CITROEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-CITROEN' :
            CarBrand = 'CITROEN'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'DAEWOO' :
            CarBrand = 'DAEWOO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '大宇' :
            CarBrand = 'DAEWOO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '成運' :
            CarBrand = 'DAEWOO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '成運牌' :
            CarBrand = 'DAEWOO'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'DAF' :
            CarBrand = 'DAF'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '達富' :
            CarBrand = 'DAF'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'DA1HATSU' :
            CarBrand = 'DAIHATSU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'DAIHATSU' :
            CarBrand = 'DAIHATSU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-DAIHATSU' :
            CarBrand = 'DAIHATSU'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'FORD' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'FORD MOTORCOMPA' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Ford 福特' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-FORD' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-福特六和' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '福特' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '福特六和' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '福特六和\u3000\u3000\u3000K' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '褔特六和' :
            CarBrand = 'FORD'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'HINO' :
            CarBrand = 'HINO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '日野' :
            CarBrand = 'HINO'
            tmp_list.append(CarBrand)
            
        elif tmp_list[col_index]== 'HONDA' :
            CarBrand = 'HONDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Honda 本田' :
            CarBrand = 'HONDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '本田' :
            CarBrand = 'HONDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-HONDA' :
            CarBrand = 'HONDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-本田' :
            CarBrand = 'HONDA'
            tmp_list.append(CarBrand)
       #### problems with aggregation ########################## 
        elif tmp_list[col_index]== 'HYUNDAI' :
            CarBrand = 'HYUNDAI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Hyundai 現代' :
            CarBrand = 'HYUNDAI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'SANYANG' :
            CarBrand = 'HYUNDAI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '現代' :
            CarBrand = 'HYUNDAI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-HYUNDAI' :
            CarBrand = 'HYUNDAI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-三陽' :
            CarBrand = 'HYUNDAI'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'SSANG YONG' :
            CarBrand = 'SsangYong'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'SSANGYONG' :
            CarBrand = 'sangYong'
            tmp_list.append(CarBrand)
        
        
        elif tmp_list[col_index]== 'ISUZU' :
            CarBrand = 'ISUZU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'ISUZU/KYOKUTO' :
            CarBrand = 'ISUZU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '五十鈴' :
            CarBrand = 'ISUZU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-五十鈴' :
            CarBrand = 'ISUZU'
            tmp_list.append(CarBrand)
            
        elif tmp_list[col_index]== 'KIA' :
            CarBrand = 'KIA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-KIA' :
            CarBrand = 'KIA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '起亞' :
            CarBrand = 'KIA'
            tmp_list.append(CarBrand)    
        
        elif tmp_list[col_index]== 'LAND ROVER' :
            CarBrand = 'LAND ROVER'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'LAND-ROVER' :
            CarBrand = 'LAND ROVER'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'LANDROVER' :
            CarBrand = 'LAND ROVER'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'RAND ROVER' :
            CarBrand = 'LAND ROVER'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== '監-LAND ROVER' :
            CarBrand = 'LAND ROVER'
            tmp_list.append(CarBrand) 
        
        elif tmp_list[col_index]== 'LEUXS' :
            CarBrand = 'LEXUS'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'LEXUS' :
            CarBrand = 'LEXUS'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'Lexus 凌志' :
            CarBrand = 'LEXUS'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== '監-LEXUS' :
            CarBrand = 'LEXUS'
            tmp_list.append(CarBrand) 
        
        elif tmp_list[col_index]== 'MAN' :
            CarBrand = 'MAN'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== '猛獅' :
            CarBrand = 'MAN'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== '至遠' :
            CarBrand = 'MAN'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== '賽德卡' :
            CarBrand = 'MAN'
            tmp_list.append(CarBrand) 
        
        elif tmp_list[col_index]== 'IMAZDA' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand) 
        elif tmp_list[col_index]== 'MAEDA' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MAZDA' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MAZDA6' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Mazda 馬自達' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-MAZDA' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-馬自達' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '馬自達' :
            CarBrand = 'MAZDA'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'MCLAREN' :
            CarBrand = 'MCLAREN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'McLaren' :
            CarBrand = 'MCLAREN'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'MITSUBISHI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'FUSO' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MISUBISHI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUB1SHI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBIHI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISH' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISHI FUSO' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISHI ROSA' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISHI(FUSO' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISHIFUSO' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISHJ' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISHZ' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBISMI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'MITSUBSHI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Mitsubishi 三菱(中華)' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'NITSUBISHI' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'mitsubishi' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '三菱' :
            CarBrand = 'MITSUBISHI'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'NISSAN' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'N1SSAN' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'NISSAN DIESEL' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'NISSANDIESEL' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Nissan 日產' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'YUELOONG' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '日產' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '日產(NISSAN)' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '日產NISSAN' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '日產柴油' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-NISSAN' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-日產' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-裕隆' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '裕隆' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '裕隆東風' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '裕隆酷比' :
            CarBrand = 'NISSAN'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'OFEL' :
            CarBrand = 'OPEL'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'OPEL' :
            CarBrand = 'OPEL'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '台灣通用歐普' :
            CarBrand = 'OPEL'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '歐普' :
            CarBrand = 'OPEL'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '通用歐普' :
            CarBrand = 'OPEL'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'PEUGEOT' :
            CarBrand = 'PEUGEOT'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-PEUGEOT' :
            CarBrand = 'PEUGEOT'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '羽田標緻' :
            CarBrand = 'PEUGEOT'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'PROTON' :
            CarBrand = 'PROTON'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-PROTON' :
            CarBrand = 'PROTON'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'RENAULT' :
            CarBrand = 'RENAULT'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'REANULT' :
            CarBrand = 'RENAULT'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '雷諾' :
            CarBrand = 'RENAULT'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'ROLLS-ROYCE' :
            CarBrand = 'ROLLS-ROYCE'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'ROLLSROYCE' :
            CarBrand = 'ROLLS-ROYCE'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'SAAB' :
            CarBrand = 'SAAB'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-SAAB' :
            CarBrand = 'SAAB'
            tmp_list.append(CarBrand)
        
        
        elif tmp_list[col_index]== 'SCANIA' :
            CarBrand = 'SCANIA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'SCANZA' :
            CarBrand = 'SCANIA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '斯堪尼亞' :
            CarBrand = 'SCANIA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '福方' :
            CarBrand = 'SCANIA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '福方牌' :
            CarBrand = 'SCANIA'
            tmp_list.append(CarBrand)
        
        #### problem here #### didnt notice the difference in excel, maybe need to transform later
        elif tmp_list[col_index]== 'SKODA' :
            CarBrand = 'SKODA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-SKODA' :
            CarBrand = 'SKODA'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'SMART' :
            CarBrand = 'SMART'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'smart' :
            CarBrand = 'SMART'
            tmp_list.append(CarBrand)
        
        #### aggregate together ####
        elif tmp_list[col_index]== '監-SUBARU' :
            CarBrand = 'SUBARU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'SUBARU' :
            CarBrand = 'SUBARU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Subaru 速霸陸' :
            CarBrand = 'SUBARU'
            tmp_list.append(CarBrand)
        #### AGGREGATE ####
        elif tmp_list[col_index]== '大慶' :
            CarBrand = 'SUBARU'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '大慶SUBARU' :
            CarBrand = 'SUBARU'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'SUZUKI' :
            CarBrand = 'SUZUKI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Suzuki 鈴木' :
            CarBrand = 'SUZUKI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-SUZUKI' :
            CarBrand = 'SUZUKI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-鈴木' :
            CarBrand = 'SUZUKI'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '鈴木' :
            CarBrand = 'SUZUKI'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'TESLA' :
            CarBrand = 'TESLA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Tesla' :
            CarBrand = 'TESLA'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'TOYOTA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'ROYOTA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'TOTOTA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'TOYOA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'TOYTA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'Toyota 豐田(國瑞)' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'YOYOTA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '國瑞' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-TOYOTA' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-國瑞' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '豐田' :
            CarBrand = 'TOYOTA'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'UD' :
            CarBrand = 'UD TRUCKS'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'UD TRUCKS' :
            CarBrand = 'UD TRUCKS'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '優迪' :
            CarBrand = 'UD TRUCKS'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '優迪卡車' :
            CarBrand = 'UD TRUCKS'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'VOLKS WAGEN' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'V.W' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'V.W.' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VOLKS' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VOLKSWAEN' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VW' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VW 福斯' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VW-T4' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-VOLKSWAGEN' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '福斯' :
            CarBrand = 'VOLKS WAGEN'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== 'VOLV0' :
            CarBrand = 'VOLVO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VOLVO' :
            CarBrand = 'VOLVO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== 'VOVLO' :
            CarBrand = 'VOLVO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '富豪' :
            CarBrand = 'VOLVO'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-VOLVO' :
            CarBrand = 'VOLVO'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '三富' :
            CarBrand = '三富'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '三富雷諾' :
            CarBrand = '三富'
            tmp_list.append(CarBrand)
        
        
        
        elif tmp_list[col_index]== '中華' :
            CarBrand = '中華'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-中華' :
            CarBrand = '中華'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '昇鋒' :
            CarBrand = '昇鋒'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '昇鋒猛獅' :
            CarBrand = '昇鋒'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '昇鋒金旅' :
            CarBrand = '昇鋒'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '納智捷' :
            CarBrand = '納智捷'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-納智捷' :
            CarBrand = '納智捷'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '陝汽雄獅曼' :
            CarBrand = '陝汽雄獅曼'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '雄獅曼' :
            CarBrand = '陝汽雄獅曼'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '健益' :
            CarBrand = '健益'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '健益福田' :
            CarBrand = '健益'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '順益' :
            CarBrand = '順益'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '順益牌' :
            CarBrand = '順益'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '新凱' :
            CarBrand = '新凱'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '新凱牌' :
            CarBrand = '新凱'
            tmp_list.append(CarBrand)
        
        elif tmp_list[col_index]== '慶' :
            CarBrand = '慶眾'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '慶#3E2J#' :
            CarBrand = '慶眾'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '慶\uef1c' :
            CarBrand = '慶眾'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '慶眾' :
            CarBrand = '慶眾'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-慶' :
            CarBrand = '慶眾'
            tmp_list.append(CarBrand)
        elif tmp_list[col_index]== '監-慶眾' :
            CarBrand = '慶眾'
            tmp_list.append(CarBrand)
        
        else :
            CarBrand = tmp_list[col_index]
            tmp_list.append(CarBrand)
        
        
        car_list.append(tmp_list)
    return car_list

# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users//Administrator//Documents//code//data//resting_agent//TRIP_utf8.txt', encoding='utf-8', low_memory=False, sep='\t', na_filter= None)

# %%
#total_list = grouping_brand(df, 11)
